# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/processed/student-performance-dataset.csv')

# %%
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# df.groupby('age')['G3'].median()
# Out:
# array([15, 16, 17, 18, 19, 20, 21, 22], dtype=int64)

# %%
df.groupby('age')['G3'].median()
# (df.groupby(['cluster', 'org'], as_index=False).mean()
#             .groupby('cluster')['time'].mean())
# Out[59]:
# cluster
# 1          15
# 2          54
# 3           6
# Name: time, dtype: int64
# Out:
# age
# 15    12.0
# 16    12.0
# 17    12.0
# 18    11.0
# 19    10.0
# 20    12.0
# 21    10.0
# 22     6.5
# Name: G3, dtype: float64

# %%
def draw_plot_median(attr):
    a = df[attr].unique()
    a.sort()
    plt.scatter(a, df.groupby(attr)['G3'].median())
    plt.show()

# %%
def draw_plot_mean(attr):
    a = df[attr].unique()
    a.sort()
    plt.scatter(a, df.groupby(attr)['G3'].mean())
    plt.show()

# %%
def draw_plot(attr):
    plt.scatter(df[attr], df['G3'])
    plt.show()

# %%
def draw_plots(attr):
    draw_plot_mean(attr)
    draw_plot_median(attr)
    draw_plot(attr)

# %%
draw_plots('age')

# %%
draw_plots('sex')

# %%
draw_plots('studytime')

# %%
draw_plots('G1')

# %%
draw_plots('G2')

# %%
draw_plots('G3')

# %%
draw_plots('Medu')

# %%
draw_plots('Walc')

# %%
draw_plots('Dalc')

# %%
draw_plots('absences')

# %%
# a = df['absences'].unique()
# a.sort()
#
# b = df.groupby('absences')['G3'].median()
# plt.scatter(a, b)
# plt.show()

# %%
draw_plots('famrel')

# %%
# axes.set_xlim([xmin, xmax])
# axes.set_ylim([ymin, ymax])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-9a9cec0fdbec> in <module>
# ----> 1 axes.set_xlim([0, 10])
#       2
#
# NameError: name 'axes' is not defined

# %%
draw_plots('Fedu')

# %%
draw_plots('school')

# %%
draw_plots('address')

# %%
draw_plots('Pstatus')

# %%
draw_plots('Mjob')

# %%
draw_plots('Fjob')

# %%
draw_plots('guardian')

# %%
draw_plots('famsize')

# %%
draw_plots('reason')

# %%
draw_plots('traveltime')

# %%
draw_plots('studytime')

# %%
draw_plots('failures')

# %%
draw_plots('schoolsup')

# %%
draw_plots('famsup')

# %%
draw_plots('activities')

# %%
draw_plots('paid')

# %%
draw_plots('internet')

# %%
draw_plots('nursery')

# %%
draw_plots('higher')

# %%
draw_plots('romantic')

# %%
draw_plots('freetime')

# %%
draw_plots('goout')

# %%
draw_plots('health')
