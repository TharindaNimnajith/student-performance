# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/processed/student-performance-dataset.csv')

# %%
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['sex'].value_counts()
# Out:
# F    591
# M    453
# Name: sex, dtype: int64

# %%
fig = plt.figure()
ax = df['sex'].value_counts().plot(kind='pie',
                                   labels=['female', 'male'],
                                   autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Gender')
plt.legend()
fig.savefig('plots/gender.png', facecolor='white')
plt.show()

# %%
df['age'].value_counts()
# Out:
# 16    281
# 17    277
# 18    222
# 15    194
# 19     56
# 20      9
# 21      3
# 22      2
# Name: age, dtype: int64

# %%
fig = plt.figure()
df['age'].value_counts().plot(kind='bar')
plt.title('Age')
plt.xlabel('age')
plt.ylabel('count')
fig.savefig('plots/age.png', facecolor='white')
plt.show()

# %%
df['address'].value_counts()
# Out:
# U    759
# R    285
# Name: address, dtype: int64

# %%
fig = plt.figure()
ax = df['address'].value_counts().plot(kind='pie',
                                       labels=['urban', 'rural'],
                                       autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Address')
plt.legend()
fig.savefig('plots/address.png', facecolor='white')
plt.show()

# %%
df['famsize'].value_counts()
# Out:
# GT3    738
# LE3    306
# Name: famsize, dtype: int64

# %%
fig = plt.figure()
ax = df['famsize'].value_counts().plot(kind='pie',
                                       labels=['3 or less', 'more than 3'],
                                       autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Family Size')
plt.legend()
fig.savefig('plots/family_size.png', facecolor='white')
plt.show()

# %%
df['Mjob'].value_counts()
# Out:
# other       399
# services    239
# at_home     194
# teacher     130
# health       82
# Name: Mjob, dtype: int64

# %%
fig = plt.figure()
ax = df['Mjob'].value_counts().plot(kind='pie',
                                    autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Mother\'s Job')
plt.legend()
fig.savefig('plots/mothers_job.png', facecolor='white')
plt.show()

# %%
df['Fjob'].value_counts()
# Out:
# other       584
# services    292
# teacher      65
# at_home      62
# health       41
# Name: Fjob, dtype: int64

# %%
fig = plt.figure()
ax = df['Fjob'].value_counts().plot(kind='pie',
                                    autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Father\'s Job')
plt.legend()
fig.savefig('plots/fathers_job.png', facecolor='white')
plt.show()

# %%
df['reason'].value_counts()
# Out:
# course        430
# home          258
# reputation    248
# other         108
# Name: reason, dtype: int64

# %%
fig = plt.figure()
ax = df['reason'].value_counts().plot(kind='pie',
                                      labels=['close to home', 'school reputation', 'course preference', 'other'],
                                      autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Reason for School Selection')
plt.legend()
fig.savefig('plots/reason_for_school_selection.png', facecolor='white')
plt.show()

# %%
df['guardian'].value_counts()
# Out:
# mother    728
# father    243
# other      73
# Name: guardian, dtype: int64

# %%
fig = plt.figure()
ax = df['guardian'].value_counts().plot(kind='pie',
                                        autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Guardian')
plt.legend()
fig.savefig('plots/guardian.png', facecolor='white')
plt.show()

# %%
df['Pstatus'].value_counts()
# Out:
# T    923
# A    121
# Name: Pstatus, dtype: int64

# %%
fig = plt.figure()
ax = df['Pstatus'].value_counts().plot(kind='pie',
                                       labels=['living together', 'apart'],
                                       autopct='%1.0f%%')
ax.yaxis.set_visible(False)
plt.title('Parent\'s Cohabitation Status')
plt.legend()
fig.savefig('plots/parents_cohabitation_status.png', facecolor='white')
plt.show()

# %%
df['Medu'].value_counts()
# Out:
# 4    306
# 2    289
# 3    238
# 1    202
# 0      9
# Name: Medu, dtype: int64

# %%
fig = plt.figure(figsize=(12, 18))
ax = df['Medu'].value_counts().plot(kind='bar')
plt.title('Mother\'s Education')
plt.xlabel('education level')
plt.ylabel('count')
ax.set_xticklabels(['higher education', 'secondary education', '5th to 9th grade', 'primary education', 'none'])
fig.savefig('plots/mothers_education.png', facecolor='white')
plt.show()

# %%
df['Fedu'].value_counts()
# Out:
# 2    324
# 1    256
# 3    231
# 4    224
# 0      9
# Name: Fedu, dtype: int64

# %%
fig = plt.figure(figsize=(12, 18))
ax = df['Fedu'].value_counts().plot(kind='bar')
plt.title('Father\'s Education')
plt.xlabel('education level')
plt.ylabel('count')
ax.set_xticklabels(['higher education', 'secondary education', '5th to 9th grade', 'primary education', 'none'])
fig.savefig('plots/fathers_education.png', facecolor='white')
plt.show()
